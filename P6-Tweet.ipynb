# %% [markdown]
# # Operations on Tweets Dataset
# Implement the following operations on Tweets dataset using NLTK libraries
#
# 1. Data Cleaning
# 2. Rank most frequently occurring 15 n-grams (bigrams and trigrams) in the given tweets dataset.
# 3. Visualize most frequently occurring 15 n-grams(bigram and trigrams) in the given tweets dataset.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/anant/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv('Resources/ngram_tweets.csv', usecols=['text'])
df.head()
# Out:
#                                                 text
# 0                     LOSER! https://t.co/p5imhMJqS1
# 1  Most of the money raised by the RINO losers of...
# 2  ....because they don’t know how to win and the...
# 3  ....lost for Evan “McMuffin” McMullin (to me)....
# 4  ....get even for all of their many failures. Y...

# %% [markdown]
# ## Data Cleaning

# %%
import re
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
sw = stopwords.words('english')
words = df['text'].to_list()
words = " ".join(word.lower() for word in words)
words = re.sub(r"[^\w\s]", '', words).split()
words = [lem.lemmatize(word) for word in words if word not in sw]
print(words)
# Out:
# ['loser', 'httpstcop5imhmjqs1', 'money', 'raised', 'rino', 'loser', 'socalled', 'lincoln', 'project', 'go', 'pocket', 'ive', 'done', 'judge', 'tax', 'regulation', 'healthcare', 'military', 'vet', 'choice', 'amp', 'protecting', 'great', '2a', 'love', 'trump', 'problem', 'beat', 'dont', 'know', 'win', 'socalled', 'lincoln', 'project', 'disgrace', 'honest', 'abe', 'dont', 'know', 'kellyanne', 'deranged', 'loser', 'husband', 'moonface', 'must', 'really', 'bad', 'john', 'weaver', 'lost', 'big', 'kasich', 'crazed', 'rick', 'wilson', 'lost', 'evan', 'mcmuffin', 'mcmullin', 'steve', 'schmidt', 'amp', 'reed', 'galvin', 'lost', 'john', 'mccain', 'romneys', 'campaign', 'manager', 'lost', 'big', 'amp', 'jennifer', 'horn', 'got', 'thrown', 'new', 'hampshire', 'republican', 'party', 'theyre', 'loser', 'abe', 'lincoln', 'republican', 'smile', 'get', 'even', 'many', 'failure', 'see', 'loser', 'type', 'dont', 'care', '252', 'new', 'federal', 'judge', '2', 'great', 'supreme', 'court', 'justice', 'rebuilt', 'military', 'protected', '2nd', 'amendment', 'biggest', 'ever', 'tax', 'amp', 'regulation', 'cut', 'much', 'didnt', 'use', 'cryin', 'chuck', 'schumer', 'compared', 'senator', 'brought', 'home', 'state', 'brought', 'little', 'back', 'ny', 'totally', 'overrated', 'loser', 'one', 'thing', 'given', 'salt', 'never', 'even', 'called', 'stop', 'wonder', 'cuomo', 'amp', 'others', 'cant', 'stand', 'aoc', 'fake', 'news', 'loser', 'httpstco3rhcbzogms', 'wall', 'street', 'journal', 'editorial', 'board', 'doesnt', 'clue', 'fight', 'win', 'view', 'tariff', 'amp', 'trade', 'loser', 'u', 'winner', 'country', 'including', 'china', 'followed', 'standard', 'wed', 'country', 'left', 'love', 'sleepy', 'joe', 'pocahontas', 'working', 'conjunction', 'democrat', 'party', 'totally', 'destroyed', 'campaign', 'bernie', 'sander', 'would', 'quit', '3', 'day', 'earlier', 'sander', 'would', 'beaten', 'biden', 'route', 'wouldnt', 'even', 'close', 'also', 'got', 'two', 'loser', 'support', 'sleepy', 'joe', 'elizabeth', 'pocahontas', 'warren', 'mini', 'mike', 'loser', 'night', 'didnt', 'even', 'come', 'close', 'winning', 'home', 'state', 'massachusetts', 'well', 'sit', 'back', 'husband', 'nice', 'cold', 'beer', 'biggest', 'loser', 'tonight', 'far', 'mini', 'mike', 'bloomberg', 'political', 'consultant', 'took', 'ride', '700', 'million', 'washed', 'drain', 'got', 'nothing', 'nickname', 'mini', 'mike', 'complete', 'destruction', 'reputation', 'way', 'go', 'mike', 'socalled', 'reporter', 'named', 'johnjharwood', 'bombed', 'badly', '2016', 'presidential', 'debate', 'thought', 'going', 'immediately', 'fired', 'mini', 'mike', 'type', 'performance', 'fake', 'news', 'cnn', 'total', 'loser', 'people', 'south', 'carolina', 'tom', 'steyer', 'joke', 'laughed', 'everyone', 'total', 'incompetent', 'made', 'money', 'coal', 'hate', 'coal', 'see', 'fawning', 'crazy', 'bernie', 'chance', 'loser', 'south', 'carolina', 'doesnt', 'deserve', 'vote', 'rt', 'byronyork', 'amusing', 'first', 'bloomberg', 'called', 'biden', 'buttigieg', 'klobuchar', 'quit', 'race', 'hey', 'loser', 'leave', 'mike', 'te', 'mini', 'mike', 'bloomberg', 'loser', 'money', 'cant', 'debate', 'zero', 'presence', 'see', 'reminds', 'tiny', 'version', 'jeb', 'low', 'energy', 'bush', 'jeb', 'political', 'skill', 'treated', 'black', 'community', 'much', 'better', 'mini', 'httpstcoqief5vhjdr', 'steyer', 'major', 'loser', 'doesnt', 'get', 'second', 'time', 'bernie', 'httpstcofxzh8znhks', 'two', 'stone', 'cold', 'loser', 'amazon', 'wp', 'almost', 'every', 'story', 'made', 'lie', 'like', 'corrupt', 'pol', 'shifty', 'schiff', 'fraudulently', 'made', 'call', 'ukraine', 'fiction', 'httpstco0oad0738ng', 'rt', 'repmattgaetz', 'lot', 'moderate', 'dems', 'recognize', 'political', 'loser', 'impeachment', 'istheyre', 'encouraging', 'leadersh', 'dont', 'get', 'foxnews', 'put', 'loser', 'like', 'repswalwell', 'got', 'zero', 'presidential', 'candidate', 'quitting', 'pramila', 'jayapal', 'david', 'cicilline', 'others', 'radical', 'left', 'hater', 'de ...

# %% [markdown]
# ## Ranking and Visualize

# %%
import matplotlib.pyplot as plt
def graph(k):
    ngram = nltk.ngrams(words, k)
    sr = pd.Series(ngram).value_counts()
    print(sr[:15])
    sr[:15].plot.bar() 
    plt.title("15 Most Freq. Occuring for k = " +str(k))
    plt.ylabel("No. of occurance")
    plt.ylabel("n_gram")

# %%
graph(3)
# Out:
# (hater, amp, loser)             10
# (separate, winner, loser)        8
# (new, twist, fate)               6
# (reacts, new, twist)             6
# (person, reacts, new)            6
# (loser, person, reacts)          6
# (winner, loser, person)          6
# (hater, loser, happy)            6
# (ego, ill, show)                 5
# (ill, show, loser)               5
# (including, hater, loser)        5
# (everyone, including, hater)     5
# (without, ego, ill)              5
# (stone, cold, loser)             4
# (trying, mike, ditka)            4
# Name: count, dtype: int64

# %%
graph(2)
# Out:
# (hater, loser)        42
# (total, loser)        32
# (loser, hater)        14
# (amp, loser)          13
# (donald, trump)       11
# (hater, amp)          11
# (separate, winner)     8
# (winner, loser)        8
# (loser, like)          6
# (loser, happy)         6
# (wear, wig)            6
# (loser, person)        6
# (person, reacts)       6
# (reacts, new)          6
# (new, twist)           6
# Name: count, dtype: int64
